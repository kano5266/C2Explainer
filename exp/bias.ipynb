# %%
import sys
sys.path.append('../src')

import pickle

import torch
import torch.nn.functional as F
import random

from cf_explainer.gcn_conv import GCNConv
from torch.nn import Linear, Sequential, BatchNorm1d, ReLU
import torch_geometric
from torch_geometric.explain import Explainer
from torch_geometric.nn import SAGEConv, GATConv, GINConv, GIN
from cf_explainer import C2Explainer
from cf_explainer.utils import seed_everything

import numpy as np

import networkx as nx
from pyvis.network import Network

from tqdm.auto import tqdm

import pickle

'''Config parameters'''
use_cuda_if_available = True
device = torch.device('cuda' if torch.cuda.is_available() and use_cuda_if_available else 'cpu')

# seed_everything(42, deterministic=True)
# if error when setting use_deterministic_algorithms(True)
# try this:
# %env CUBLAS_WORKSPACE_CONFIG=:4096:8

print("PyTorch version:", torch.__version__)
print("PyTorch device:", device)
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8
# PyTorch version: 2.0.1
# PyTorch device: cuda

# %%
def results(num_perturbs, prop_perturbs):
    print("######")
    if len(num_perturbs) != 0:
        size = sum(num_perturbs)/(2*len(num_perturbs))
        prop = sum(prop_perturbs)/len(prop_perturbs)
    else:
        size = "N/A"
        prop = "N/A"
    print(f"size: {size}, num_success: {len(num_perturbs)}, prop_perturbs: {prop}")
    print("finished")
    return size, prop


def explaine(model, data, explainer, seed=42):
    seed_everything(seed, deterministic=True)
    result = []
    
    condition = (data.test_mask.cpu() | data.val_mask.cpu())
    df_cf = np.where(condition)[0].tolist()

    print(len(df_cf))
    
    explainer = Explainer(
        model=model,
        algorithm=explainer,
        explanation_type='model',
        node_mask_type=None,
        edge_mask_type='object',
        model_config=dict(
            mode='multiclass_classification',
            task_level='node',
            return_type='raw',
        ), 
    )
    
    # cfs = []
    num_perturbs = []
    prop_perturbs = []

    for i in tqdm(df_cf):
        explanation = explainer(data.x, data.edge_index, index=i)
        
        if hasattr(explanation, "perturbs"):
            if explanation.perturbs < 20:
                # cfs.append(explanation.cf)
                num_perturbs.append(explanation.perturbs)
                prop_perturbs.append(explanation.prop_perturbs)
    
    size, prop = results(num_perturbs, prop_perturbs)
    
    result.append([len(df_cf), size, len(num_perturbs), prop])
    print(f"Fedility: {len(num_perturbs)/len(df_cf)}, Num_perturbs: {size}, Similarity: {1-prop}")
    return result

# %% [markdown]
# # GNNExplainer + GCN + LoanDecision

# %%
class GCN(torch.nn.Module):
    def __init__(self, nhid, nout, dropout):
        super().__init__()
        self.conv1 = GCNConv(2, nhid, normalize=True)
        self.conv2 = GCNConv(nhid, nhid, normalize=True)
        self.conv3 = GCNConv(nhid, nout, normalize=True)
        self.lin1 = Linear(nout, nout)
        self.lin2 = Linear(nout,2)
        self.dropout = dropout

    def forward(self, x, edge_index, edge_weight=None):
        x = self.conv1(x, edge_index, edge_weight)
        x = x.relu()
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index, edge_weight)
        x = x.relu()
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv3(x, edge_index, edge_weight)
        x = self.lin1(x)
        x = x.relu()
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.lin2(x)
        return x
    
model = torch.load("../models/GCN_LoanDecision.pt")
model

with open("../data/LoanDecision.pickle", "rb") as f:
	data = pickle.load(f)
    
data
# Out:
# Data(edge_index=[2, 3950], num_nodes=1000, x=[1000, 2], y=[1000], train_mask=[1000], val_mask=[1000], test_mask=[1000])

# %%
def explaine(model, data, explainer, seed=42):
    seed_everything(seed, deterministic=True)
    result = []
    
    ###
    # only gender = 1
    condition = ((data.test_mask.cpu() | data.val_mask.cpu()) & data.x[:,1].to(bool).cpu())
    ###
    df_cf = np.where(condition)[0].tolist()

    print(len(df_cf))
    
    explainer = Explainer(
        model=model,
        algorithm=explainer,
        explanation_type='model',
        node_mask_type=None,
        edge_mask_type='object',
        model_config=dict(
            mode='multiclass_classification',
            task_level='node',
            return_type='raw',
        ), 
    )
    
    # cfs = []
    num_perturbs = []
    prop_perturbs = []

    for i in tqdm(df_cf):
        explanation = explainer(data.x, data.edge_index, index=i)
        
        if hasattr(explanation, "perturbs"):
            if explanation.perturbs < 20:
                # cfs.append(explanation.cf)
                num_perturbs.append(explanation.perturbs)
                prop_perturbs.append(explanation.prop_perturbs)
    
    size, prop = results(num_perturbs, prop_perturbs)
    
    result.append([len(df_cf), size, len(num_perturbs), prop])
    print(f"Fedility: {len(num_perturbs)/len(df_cf)}, Num_perturbs: {size}, Similarity: {1-prop}")
    return result

explainer = ARExplainer(epochs=1000, lr=0.001, undirected=True, AR_mode=True)
result4 = explaine(model, data, explainer, seed=42)
# Out:
# 118
#   0%|          | 0/118 [00:00<?, ?it/s]
# num_cfs:2, min_perturbs:130.0, prop_perturbs:0.04542278125882149, cf_label 1
# =========
# num_cfs:201, min_perturbs:368.0, prop_perturbs:0.1588946431875229, cf_label 0
# =========
# num_cfs:686, min_perturbs:2.0, prop_perturbs:0.001287001301534474, cf_label 0
# =========
# num_cfs:804, min_perturbs:16.0, prop_perturbs:0.009378663264214993, cf_label 0
# =========
# num_cfs:571, min_perturbs:2.0, prop_perturbs:0.002583979396149516, cf_label 0
# =========
# num_cfs:691, min_perturbs:4.0, prop_perturbs:0.007518797181546688, cf_label 1
# =========
# num_cfs:532, min_perturbs:4.0, prop_perturbs:0.0034246575087308884, cf_label 1
# =========
# num_cfs:49, min_perturbs:2.0, prop_perturbs:0.0020964359864592552, cf_label 1
# =========
# num_cfs:23, min_perturbs:26.0, prop_perturbs:0.018465910106897354, cf_label 1
# =========
# num_cfs:699, min_perturbs:2.0, prop_perturbs:0.0030120480805635452, cf_label 0
# =========
# num_cfs:65, min_perturbs:2.0, prop_perturbs:0.001251564477570355, cf_label 1
# =========
# num_cfs:294, min_perturbs:4.0, prop_perturbs:0.00716845877468586, cf_label 1
# =========
# num_cfs:164, min_perturbs:2.0, prop_perturbs:0.0020833334419876337, cf_label 1
# =========
# num_cfs:850, min_perturbs:2.0, prop_perturbs:0.0026385225355625153, cf_label 0
# =========
# num_cfs:77, min_perturbs:44.0, prop_perturbs:0.0788530483841896, cf_label 0
# =========
# num_cfs:736, min_perturbs:2.0, prop_perturbs:0.0117647061124444, cf_label 1
# =========
# num_cfs:280, min_perturbs:2.0, prop_perturbs:0.0012562813935801387, cf_label 0
# =========
# num_cfs:251, min_perturbs:2.0, prop_perturbs:0.007692307699471712, cf_label 1
# =========
# num_cfs:408, min_perturbs:10.0, prop_perturbs:0.008818341419100761, cf_label 0
# =========
# num_cfs:732, min_perturbs:2.0, prop_perturbs:0.003367003286257386, cf_label 0
# =========
# num_cfs:248, min_perturbs:94.0, prop_perturbs:0.16206896305084229, cf_label 0
# =========
# num_cfs:198, min_perturbs:124.0, prop_perturbs:0.13135592639446259, cf_label 0
# =========
# num_cfs:199, min_perturbs:4.0, prop_perturbs:0.014492753893136978, cf_label 1
# =========
# num_cfs:228, min_perturbs:126.0, prop_perturbs:0.12989690899848938, cf_label 0
# =========
# num_cfs:348, min_perturbs:2.0, prop_perturbs:0.0016583747928962111, cf_label 0
# =========
# num_cfs:673, min_perturbs:4.0, prop_perturbs:0.0037807184271514416, cf_label 0
# =========
# num_cfs:670, min_perturbs:2.0, prop_perturbs:0.0045045046135783195, cf_label 0
# =========
# num_cfs:221, min_perturbs:2.0, prop_perturbs:0.0036231884732842445, cf_label 1
# =========
# num_cfs:755, min_perturbs:2.0, prop_perturbs:0.004065040498971939, cf_label 0
# =========
# num_cfs:308, min_perturbs:4.0, prop_perturbs:0.0026212320663034916, cf_label 1
# =========
# num_cfs:450, min_perturbs:2.0, prop_perturbs:0.002994012087583542, cf_label 1
# =========
# num_cfs:18, min_perturbs:4.0, prop_perturbs:0.010471204295754433, cf_label 1
# =========
# num_cfs:443, min_perturbs:2.0, prop_perturbs:0.0017391304718330503, cf_label 0
# =========
# num_cfs:623, min_perturbs:2.0, prop_perturbs:0.004651162773370743, cf_label 0
# =========
# num_cfs:21, min_perturbs:2.0, prop_perturbs:0.0033003301359713078, cf_label 0
# =========
# num_cfs:523, min_perturbs:2.0, prop_perturbs:0.005319148767739534, cf_label 0
# =========
# num_cfs:65, min_perturbs:2.0, prop_perturbs:0.004672897048294544, cf_label 1
# =========
# num_cfs:517, min_perturbs:2.0, prop_perturbs:0.0018348623998463154, cf_label 0
# =========
# num_cfs:2, min_perturbs:52.0, prop_perturbs:0.18705035746097565, cf_label 1
# =========
# num_cfs:467, min_perturbs:2.0, prop_perturbs:0.0020325202494859695, cf_label 0
# =========
# num_cfs:59, min_perturbs:4.0, prop_perturbs:0.0058139534667134285, cf_label 1
# =========
# num_cfs:162, min_perturbs:2.0, prop_perturbs:0.0034722222480922937, cf_label 1
# =========
# num_cfs:151, min_perturbs:8.0, prop_perturbs:0.05797101557254791, cf_label 1
# =========
# num_cfs:971, min_perturbs:2.0, prop_perturbs:0.002053388161584735, cf_label 0
# =========
# num_cfs:761, min_perturbs:2.0, prop_perturbs:0.01315789483487606, cf_label 1
# =========
# num_cfs:266, min_perturbs:4.0, prop_perturbs:0.003327786922454834, cf_label 1
# =========
# num_cfs:868, min_perturbs:2.0, prop_perturbs:0.011111111380159855, cf_label 0
# =========
# num_cfs:367, min_perturbs:136.0, prop_perturbs:0.09497206658124924, cf_label 0
# =========
# num_cfs:76, min_perturbs:2.0, prop_perturbs:0.0033783784601837397, cf_label 1
# =========
# num_cfs:366, min_perturbs:4.0, prop_perturbs:0.008163264952600002, cf_label 1
# =========
# num_cfs:666, min_perturbs:2.0, prop_perturbs:0.0013812155229970813, cf_label 0
# =========
# num_cfs:180, min_perturbs:2.0, prop_perturbs:0.004347825888544321, cf_label 1
# =========
# num_cfs:889, min_perturbs:2.0, prop_perturbs:0.005025125574320555, cf_label 1
# =========
# num_cfs:137, min_perturbs:4.0, prop_perturbs:0.00638977624475956, cf_label 1
# =========
# num_cfs:221, min_perturbs:2.0, prop_perturbs:0.0025380710139870644, cf_label 1
# =========
# num_cfs:170, min_perturbs:4.0, prop_perturbs:0.008658008649945259, cf_label 1
# =========
# num_cfs:94, min_perturbs:2.0, prop_perturbs:0.004926108289510012, cf_label 1
# =========
# num_cfs:689, min_perturbs:2.0, prop_perturbs:0.01587301678955555, cf_label 1
# =========
# num_cfs:186, min_perturbs:2.0, prop_perturbs:0.0024449878837913275, cf_label 1
# =========
# num_cfs:87, min_perturbs:20.0, prop_perturbs:0.12195121496915817, cf_label 0
# =========
# num_cfs:405, min_perturbs:2.0, prop_perturbs:0.0013003901112824678, cf_label 1
# =========
# num_cfs:240, min_perturbs:4.0, prop_perturbs:0.0181818176060915, cf_label 1
# =========
# num_cfs:352, min_perturbs:2.0, prop_perturbs:0.002016128972172737, cf_label 1
# =========
# num_cfs:143, min_perturbs:2.0, prop_perturbs:0.002816901309415698, cf_label 1
# =========
# num_cfs:873, min_perturbs:2.0, prop_perturbs:0.001818181830458343, cf_label 0
# =========
# num_cfs:960, min_perturbs:2.0, prop_perturbs:0.005376344081014395, cf_label 0
# =========
# num_cfs:240, min_perturbs:2.0, prop_perturbs:0.0016750418581068516, cf_label 1
# =========
# num_cfs:117, min_perturbs:2.0, prop_perturbs:0.003508772002533078, cf_label 1
# =========
# num_cfs:680, min_perturbs:2.0, prop_perturbs:0.001805054140277207, cf_label 1
# =========
# num_cfs:358, min_perturbs:4.0, prop_perturbs:0.01123595517128706, cf_label 1
# =========
# num_cfs:890, min_perturbs:2.0, prop_perturbs:0.008849557489156723, cf_label 1
# =========
# num_cfs:62, min_perturbs:50.0, prop_perturbs:0.12755101919174194, cf_label 1
# =========
# num_cfs:236, min_perturbs:2.0, prop_perturbs:0.0019267823081463575, cf_label 1
# =========
# num_cfs:704, min_perturbs:2.0, prop_perturbs:0.008547008968889713, cf_label 1
# =========
# num_cfs:882, min_perturbs:4.0, prop_perturbs:0.014388489536941051, cf_label 1
# =========
# num_cfs:836, min_perturbs:4.0, prop_perturbs:0.03773584961891174, cf_label 1
# =========
# num_cfs:734, min_perturbs:2.0, prop_perturbs:0.0042553190141916275, cf_label 1
# =========
# num_cfs:209, min_perturbs:4.0, prop_perturbs:0.008620689623057842, cf_label 1
# =========
# num_cfs:444, min_perturbs:2.0, prop_perturbs:0.010416666977107525, cf_label 1
# =========
# num_cfs:168, min_perturbs:2.0, prop_perturbs:0.007575757801532745, cf_label 1
# =========
# num_cfs:487, min_perturbs:2.0, prop_perturbs:0.0018382353009656072, cf_label 1
# =========
# num_cfs:417, min_perturbs:4.0, prop_perturbs:0.007633587811142206, cf_label 1
# =========
# num_cfs:148, min_perturbs:6.0, prop_perturbs:0.005870841443538666, cf_label 1
# =========
# num_cfs:129, min_perturbs:2.0, prop_perturbs:0.0014430014416575432, cf_label 1
# =========
# num_cfs:1000, min_perturbs:2.0, prop_perturbs:0.008333333767950535, cf_label 1
# =========
# num_cfs:630, min_perturbs:2.0, prop_perturbs:0.0042553190141916275, cf_label 1
# =========
# num_cfs:522, min_perturbs:4.0, prop_perturbs:0.014084506779909134, cf_label 1
# =========
# num_cfs:587, min_perturbs:4.0, prop_perturbs:0.008928571827709675, cf_label 1
# =========
# num_cfs:324, min_perturbs:2.0, prop_perturbs:0.009523809887468815, cf_label 1
# =========
# num_cfs:972, min_perturbs:2.0, prop_perturbs:0.010989011265337467, cf_label 1
# =========
# num_cfs:733, min_perturbs:2.0, prop_perturbs:0.006896551698446274, cf_label 0
# =========
# num_cfs:958, min_perturbs:4.0, prop_perturbs:0.006230529397726059, cf_label 1
# =========
# num_cfs:100, min_perturbs:4.0, prop_perturbs:0.007662835065275431, cf_label 1
# =========
# num_cfs:165, min_perturbs:6.0, prop_perturbs:0.007915567606687546, cf_label 1
# =========
# num_cfs:157, min_perturbs:2.0, prop_perturbs:0.008064515888690948, cf_label 1
# =========
# num_cfs:100, min_perturbs:2.0, prop_perturbs:0.009009009227156639, cf_label 1
# =========
# num_cfs:881, min_perturbs:2.0, prop_perturbs:0.02222222276031971, cf_label 1
# =========
# num_cfs:174, min_perturbs:2.0, prop_perturbs:0.007633587811142206, cf_label 1
# =========
# num_cfs:81, min_perturbs:4.0, prop_perturbs:0.0034246575087308884, cf_label 1
# =========
# num_cfs:177, min_perturbs:2.0, prop_perturbs:0.007518797181546688, cf_label 1
# =========
# num_cfs:170, min_perturbs:2.0, prop_perturbs:0.002197802299633622, cf_label 1
# =========
# num_cfs:78, min_perturbs:2.0, prop_perturbs:0.00390625, cf_label 1
# =========
# num_cfs:954, min_perturbs:2.0, prop_perturbs:0.02500000037252903, cf_label 1
# =========
# num_cfs:331, min_perturbs:2.0, prop_perturbs:0.004739336669445038, cf_label 1
# =========
# ######
# size: 1.4408602150537635, num_success: 93, prop_perturbs: 0.00703772995620966
# finished
# Fedility: 0.788135593220339, Num_perturbs: 1.4408602150537635, Similarity: 0.9929622411727905

# %%
def explaine(model, data, explainer, seed=42):
    seed_everything(seed, deterministic=True)
    result = []
    
    ###
    # only gender = 1
    condition = ((data.test_mask.cpu() | data.val_mask.cpu()) & ~data.x[:,1].to(bool).cpu())
    ###
    df_cf = np.where(condition)[0].tolist()

    print(len(df_cf))
    
    explainer = Explainer(
        model=model,
        algorithm=explainer,
        explanation_type='model',
        node_mask_type=None,
        edge_mask_type='object',
        model_config=dict(
            mode='multiclass_classification',
            task_level='node',
            return_type='raw',
        ), 
    )
    
    # cfs = []
    num_perturbs = []
    prop_perturbs = []

    for i in tqdm(df_cf):
        explanation = explainer(data.x, data.edge_index, index=i)
        
        if hasattr(explanation, "perturbs"):
            if explanation.perturbs < 20:
                # cfs.append(explanation.cf)
                num_perturbs.append(explanation.perturbs)
                prop_perturbs.append(explanation.prop_perturbs)
    
    size, prop = results(num_perturbs, prop_perturbs)
    
    result.append([len(df_cf), size, len(num_perturbs), prop])
    print(f"Fedility: {len(num_perturbs)/len(df_cf)}, Num_perturbs: {size}, Similarity: {1-prop}")
    return result

explainer = ARExplainer(epochs=1000, lr=0.001, undirected=True, AR_mode=True)
result4 = explaine(model, data, explainer, seed=42)
# Out:
# 82
#   0%|          | 0/82 [00:00<?, ?it/s]
# num_cfs:22, min_perturbs:312.0, prop_perturbs:0.2145804762840271, cf_label 0
# =========
# num_cfs:790, min_perturbs:2.0, prop_perturbs:0.002061855746433139, cf_label 0
# =========
# num_cfs:649, min_perturbs:2.0, prop_perturbs:0.0012180268531665206, cf_label 0
# =========
# num_cfs:528, min_perturbs:2.0, prop_perturbs:0.00119331746827811, cf_label 0
# =========
# num_cfs:27, min_perturbs:92.0, prop_perturbs:0.33576643466949463, cf_label 1
# =========
# num_cfs:704, min_perturbs:2.0, prop_perturbs:0.001240694778971374, cf_label 0
# =========
# num_cfs:76, min_perturbs:6.0, prop_perturbs:0.005217391531914473, cf_label 1
# =========
# num_cfs:28, min_perturbs:6.0, prop_perturbs:0.014018691144883633, cf_label 1
# =========
# num_cfs:47, min_perturbs:6.0, prop_perturbs:0.005464480724185705, cf_label 1
# =========
# num_cfs:497, min_perturbs:2.0, prop_perturbs:0.0049019609577953815, cf_label 0
# =========
# num_cfs:513, min_perturbs:2.0, prop_perturbs:0.006802720949053764, cf_label 0
# =========
# num_cfs:179, min_perturbs:2.0, prop_perturbs:0.0032573288772255182, cf_label 1
# =========
# num_cfs:959, min_perturbs:2.0, prop_perturbs:0.004166666883975267, cf_label 1
# =========
# num_cfs:891, min_perturbs:2.0, prop_perturbs:0.00283286115154624, cf_label 0
# =========
# num_cfs:72, min_perturbs:4.0, prop_perturbs:0.0041841003112494946, cf_label 1
# =========
# num_cfs:203, min_perturbs:2.0, prop_perturbs:0.0011312217684462667, cf_label 1
# =========
# num_cfs:161, min_perturbs:2.0, prop_perturbs:0.0019646366126835346, cf_label 1
# =========
# num_cfs:653, min_perturbs:2.0, prop_perturbs:0.0015772870974615216, cf_label 0
# =========
# num_cfs:808, min_perturbs:2.0, prop_perturbs:0.006756756920367479, cf_label 1
# =========
# num_cfs:868, min_perturbs:2.0, prop_perturbs:0.001402524532750249, cf_label 0
# =========
# num_cfs:155, min_perturbs:292.0, prop_perturbs:0.19518716633319855, cf_label 0
# =========
# num_cfs:12, min_perturbs:64.0, prop_perturbs:0.14678898453712463, cf_label 1
# =========
# num_cfs:305, min_perturbs:2.0, prop_perturbs:0.004694835748523474, cf_label 1
# =========
# num_cfs:44, min_perturbs:250.0, prop_perturbs:0.25406503677368164, cf_label 0
# =========
# num_cfs:178, min_perturbs:2.0, prop_perturbs:0.0021786491852253675, cf_label 1
# =========
# num_cfs:870, min_perturbs:2.0, prop_perturbs:0.0012562813935801387, cf_label 0
# =========
# num_cfs:238, min_perturbs:24.0, prop_perturbs:0.17142857611179352, cf_label 0
# =========
# num_cfs:314, min_perturbs:26.0, prop_perturbs:0.1354166716337204, cf_label 0
# =========
# num_cfs:312, min_perturbs:2.0, prop_perturbs:0.004524887073785067, cf_label 1
# =========
# num_cfs:763, min_perturbs:6.0, prop_perturbs:0.07894736528396606, cf_label 1
# =========
# num_cfs:729, min_perturbs:2.0, prop_perturbs:0.00401606410741806, cf_label 1
# =========
# num_cfs:84, min_perturbs:58.0, prop_perturbs:0.21481481194496155, cf_label 0
# =========
# num_cfs:70, min_perturbs:2.0, prop_perturbs:0.0015267175622284412, cf_label 1
# =========
# num_cfs:631, min_perturbs:4.0, prop_perturbs:0.005181347019970417, cf_label 0
# =========
# num_cfs:312, min_perturbs:4.0, prop_perturbs:0.009852216579020023, cf_label 0
# =========
# num_cfs:141, min_perturbs:4.0, prop_perturbs:0.003636363660916686, cf_label 1
# =========
# num_cfs:22, min_perturbs:4.0, prop_perturbs:0.007633587811142206, cf_label 1
# =========
# num_cfs:123, min_perturbs:36.0, prop_perturbs:0.10465116053819656, cf_label 1
# =========
# num_cfs:350, min_perturbs:4.0, prop_perturbs:0.008438818156719208, cf_label 1
# =========
# num_cfs:634, min_perturbs:32.0, prop_perturbs:0.021080369129776955, cf_label 1
# =========
# num_cfs:94, min_perturbs:2.0, prop_perturbs:0.006369426846504211, cf_label 1
# =========
# num_cfs:898, min_perturbs:2.0, prop_perturbs:0.0015923567116260529, cf_label 0
# =========
# num_cfs:471, min_perturbs:2.0, prop_perturbs:0.014925372786819935, cf_label 0
# =========
# num_cfs:13, min_perturbs:2.0, prop_perturbs:0.005586592014878988, cf_label 1
# =========
# num_cfs:483, min_perturbs:4.0, prop_perturbs:0.010256410576403141, cf_label 0
# =========
# num_cfs:350, min_perturbs:4.0, prop_perturbs:0.009999999776482582, cf_label 1
# =========
# num_cfs:310, min_perturbs:2.0, prop_perturbs:0.0018281536176800728, cf_label 1
# =========
# num_cfs:778, min_perturbs:8.0, prop_perturbs:0.025641025975346565, cf_label 1
# =========
# num_cfs:855, min_perturbs:2.0, prop_perturbs:0.003389830468222499, cf_label 0
# =========
# num_cfs:793, min_perturbs:2.0, prop_perturbs:0.005347593687474728, cf_label 0
# =========
# num_cfs:37, min_perturbs:4.0, prop_perturbs:0.01005025114864111, cf_label 1
# =========
# num_cfs:546, min_perturbs:4.0, prop_perturbs:0.010256410576403141, cf_label 0
# =========
# num_cfs:803, min_perturbs:4.0, prop_perturbs:0.016393441706895828, cf_label 1
# =========
# num_cfs:39, min_perturbs:4.0, prop_perturbs:0.006430868059396744, cf_label 0
# =========
# num_cfs:443, min_perturbs:4.0, prop_perturbs:0.01600000075995922, cf_label 1
# =========
# num_cfs:231, min_perturbs:2.0, prop_perturbs:0.0015128592494875193, cf_label 1
# =========
# num_cfs:633, min_perturbs:6.0, prop_perturbs:0.10344827175140381, cf_label 1
# =========
# num_cfs:12, min_perturbs:4.0, prop_perturbs:0.01886792480945587, cf_label 1
# =========
# num_cfs:398, min_perturbs:4.0, prop_perturbs:0.05000000074505806, cf_label 1
# =========
# num_cfs:13, min_perturbs:14.0, prop_perturbs:0.0364583358168602, cf_label 1
# =========
# num_cfs:989, min_perturbs:2.0, prop_perturbs:0.008620689623057842, cf_label 1
# =========
# num_cfs:488, min_perturbs:2.0, prop_perturbs:0.004694835748523474, cf_label 1
# =========
# num_cfs:585, min_perturbs:2.0, prop_perturbs:0.008130080997943878, cf_label 1
# =========
# num_cfs:761, min_perturbs:2.0, prop_perturbs:0.00390625, cf_label 1
# =========
# num_cfs:447, min_perturbs:4.0, prop_perturbs:0.010362694039940834, cf_label 1
# =========
# num_cfs:73, min_perturbs:6.0, prop_perturbs:0.0041841003112494946, cf_label 1
# =========
# num_cfs:411, min_perturbs:2.0, prop_perturbs:0.017543859779834747, cf_label 1
# =========
# num_cfs:485, min_perturbs:4.0, prop_perturbs:0.011560693383216858, cf_label 1
# =========
# num_cfs:426, min_perturbs:8.0, prop_perturbs:0.043478261679410934, cf_label 1
# =========
# num_cfs:805, min_perturbs:2.0, prop_perturbs:0.007633587811142206, cf_label 1
# =========
# num_cfs:764, min_perturbs:2.0, prop_perturbs:0.0044843051582574844, cf_label 1
# =========
# num_cfs:144, min_perturbs:4.0, prop_perturbs:0.009523809887468815, cf_label 1
# =========
# num_cfs:571, min_perturbs:4.0, prop_perturbs:0.012121211737394333, cf_label 1
# =========
# num_cfs:418, min_perturbs:2.0, prop_perturbs:0.029411764815449715, cf_label 1
# =========
# num_cfs:299, min_perturbs:14.0, prop_perturbs:0.07954545319080353, cf_label 1
# =========
# ######
# size: 1.7538461538461538, num_success: 65, prop_perturbs: 0.012474403716623783
# finished
# Fedility: 0.7926829268292683, Num_perturbs: 1.7538461538461538, Similarity: 0.9875255823135376

# %% [markdown]
# # Biased model

# %%
def explaine(model, data, explainer, seed=42):
    seed_everything(seed, deterministic=True)
    result = []
    
    ###
    # only gender = 1
    condition = ((data.test_mask.cpu() | data.val_mask.cpu()) & data.x[:,1].to(bool).cpu())
    ###
    df_cf = np.where(condition)[0].tolist()

    print(len(df_cf))
    
    explainer = Explainer(
        model=model,
        algorithm=explainer,
        explanation_type='model',
        node_mask_type=None,
        edge_mask_type='object',
        model_config=dict(
            mode='multiclass_classification',
            task_level='node',
            return_type='raw',
        ), 
    )
    
    # cfs = []
    num_perturbs = []
    prop_perturbs = []

    for i in tqdm(df_cf):
        explanation = explainer(data.x, data.edge_index, index=i)
        
        if hasattr(explanation, "perturbs"):
            if explanation.perturbs < 20:
                # cfs.append(explanation.cf)
                num_perturbs.append(explanation.perturbs)
                prop_perturbs.append(explanation.prop_perturbs)
    
    size, prop = results(num_perturbs, prop_perturbs)
    
    result.append([len(df_cf), size, len(num_perturbs), prop])
    print(f"Fedility: {len(num_perturbs)/len(df_cf)}, Num_perturbs: {size}, Similarity: {1-prop}")
    return result

model = torch.load("../models/Biased_GCN_LoanDecision.pt")
model

explainer = ARExplainer(epochs=1000, lr=0.001, undirected=True, AR_mode=True)
result4 = explaine(model, data, explainer, seed=42)
# Out:
# 118
#   0%|          | 0/118 [00:00<?, ?it/s]
# num_cfs:895, min_perturbs:4.0, prop_perturbs:0.0014803848462179303, cf_label 0
# =========
# num_cfs:225, min_perturbs:2.0, prop_perturbs:0.0008635578560642898, cf_label 1
# =========
# num_cfs:375, min_perturbs:10.0, prop_perturbs:0.006435006391257048, cf_label 1
# =========
# num_cfs:9, min_perturbs:76.0, prop_perturbs:0.044548649340867996, cf_label 1
# =========
# num_cfs:429, min_perturbs:26.0, prop_perturbs:0.03359173238277435, cf_label 0
# =========
# num_cfs:126, min_perturbs:4.0, prop_perturbs:0.007518797181546688, cf_label 1
# =========
# num_cfs:477, min_perturbs:6.0, prop_perturbs:0.0051369862630963326, cf_label 1
# =========
# num_cfs:117, min_perturbs:2.0, prop_perturbs:0.0020964359864592552, cf_label 1
# =========
# num_cfs:306, min_perturbs:2.0, prop_perturbs:0.0025125627871602774, cf_label 1
# =========
# num_cfs:740, min_perturbs:2.0, prop_perturbs:0.0014204545877873898, cf_label 0
# =========
# num_cfs:152, min_perturbs:22.0, prop_perturbs:0.03313253074884415, cf_label 1
# =========
# num_cfs:279, min_perturbs:2.0, prop_perturbs:0.00358422938734293, cf_label 1
# =========
# num_cfs:357, min_perturbs:2.0, prop_perturbs:0.00358422938734293, cf_label 1
# =========
# num_cfs:282, min_perturbs:2.0, prop_perturbs:0.0117647061124444, cf_label 1
# =========
# num_cfs:460, min_perturbs:2.0, prop_perturbs:0.0012562813935801387, cf_label 1
# =========
# num_cfs:548, min_perturbs:2.0, prop_perturbs:0.0017636683769524097, cf_label 0
# =========
# num_cfs:780, min_perturbs:6.0, prop_perturbs:0.010101010091602802, cf_label 0
# =========
# num_cfs:67, min_perturbs:2.0, prop_perturbs:0.003448275849223137, cf_label 1
# =========
# num_cfs:353, min_perturbs:2.0, prop_perturbs:0.0021186440717428923, cf_label 1
# =========
# num_cfs:145, min_perturbs:4.0, prop_perturbs:0.014492753893136978, cf_label 1
# =========
# num_cfs:351, min_perturbs:118.0, prop_perturbs:0.12164948880672455, cf_label 0
# =========
# num_cfs:397, min_perturbs:8.0, prop_perturbs:0.006633499171584845, cf_label 0
# =========
# num_cfs:593, min_perturbs:4.0, prop_perturbs:0.0037807184271514416, cf_label 0
# =========
# num_cfs:179, min_perturbs:2.0, prop_perturbs:0.0045045046135783195, cf_label 0
# =========
# num_cfs:156, min_perturbs:2.0, prop_perturbs:0.0036231884732842445, cf_label 1
# =========
# num_cfs:788, min_perturbs:2.0, prop_perturbs:0.004065040498971939, cf_label 0
# =========
# num_cfs:301, min_perturbs:4.0, prop_perturbs:0.0026212320663034916, cf_label 1
# =========
# num_cfs:250, min_perturbs:4.0, prop_perturbs:0.005988024175167084, cf_label 1
# =========
# num_cfs:12, min_perturbs:22.0, prop_perturbs:0.06707316637039185, cf_label 1
# =========
# num_cfs:740, min_perturbs:2.0, prop_perturbs:0.005235602147877216, cf_label 1
# =========
# num_cfs:365, min_perturbs:148.0, prop_perturbs:0.12869565188884735, cf_label 0
# =========
# num_cfs:212, min_perturbs:44.0, prop_perturbs:0.10232558101415634, cf_label 0
# =========
# num_cfs:169, min_perturbs:2.0, prop_perturbs:0.005319148767739534, cf_label 0
# =========
# num_cfs:268, min_perturbs:4.0, prop_perturbs:0.009345794096589088, cf_label 1
# =========
# num_cfs:340, min_perturbs:10.0, prop_perturbs:0.02109704539179802, cf_label 1
# =========
# num_cfs:806, min_perturbs:2.0, prop_perturbs:0.0018348623998463154, cf_label 1
# =========
# num_cfs:922, min_perturbs:2.0, prop_perturbs:0.0020325202494859695, cf_label 0
# =========
# num_cfs:36, min_perturbs:2.0, prop_perturbs:0.0034722222480922937, cf_label 1
# =========
# num_cfs:674, min_perturbs:2.0, prop_perturbs:0.014492753893136978, cf_label 1
# =========
# num_cfs:909, min_perturbs:2.0, prop_perturbs:0.002053388161584735, cf_label 0
# =========
# num_cfs:140, min_perturbs:2.0, prop_perturbs:0.001663893461227417, cf_label 1
# =========
# num_cfs:848, min_perturbs:2.0, prop_perturbs:0.001396648003719747, cf_label 0
# =========
# num_cfs:173, min_perturbs:6.0, prop_perturbs:0.010135135613381863, cf_label 1
# =========
# num_cfs:483, min_perturbs:2.0, prop_perturbs:0.004081632476300001, cf_label 1
# =========
# num_cfs:603, min_perturbs:56.0, prop_perturbs:0.03867403417825699, cf_label 0
# =========
# num_cfs:53, min_perturbs:36.0, prop_perturbs:0.0782608687877655, cf_label 1
# =========
# num_cfs:536, min_perturbs:2.0, prop_perturbs:0.005025125574320555, cf_label 1
# =========
# num_cfs:715, min_perturbs:4.0, prop_perturbs:0.00638977624475956, cf_label 1
# =========
# num_cfs:749, min_perturbs:4.0, prop_perturbs:0.005076142027974129, cf_label 1
# =========
# num_cfs:255, min_perturbs:4.0, prop_perturbs:0.008658008649945259, cf_label 1
# =========
# num_cfs:190, min_perturbs:4.0, prop_perturbs:0.009852216579020023, cf_label 1
# =========
# num_cfs:98, min_perturbs:2.0, prop_perturbs:0.020408162847161293, cf_label 1
# =========
# num_cfs:538, min_perturbs:2.0, prop_perturbs:0.01587301678955555, cf_label 1
# =========
# num_cfs:540, min_perturbs:2.0, prop_perturbs:0.0024449878837913275, cf_label 1
# =========
# num_cfs:290, min_perturbs:2.0, prop_perturbs:0.012195121496915817, cf_label 1
# =========
# num_cfs:368, min_perturbs:2.0, prop_perturbs:0.0013003901112824678, cf_label 1
# =========
# num_cfs:380, min_perturbs:4.0, prop_perturbs:0.0181818176060915, cf_label 1
# =========
# num_cfs:522, min_perturbs:2.0, prop_perturbs:0.002016128972172737, cf_label 1
# =========
# num_cfs:276, min_perturbs:2.0, prop_perturbs:0.001818181830458343, cf_label 1
# =========
# num_cfs:727, min_perturbs:10.0, prop_perturbs:0.02688172087073326, cf_label 0
# =========
# num_cfs:170, min_perturbs:4.0, prop_perturbs:0.003350083716213703, cf_label 1
# =========
# num_cfs:154, min_perturbs:2.0, prop_perturbs:0.003508772002533078, cf_label 1
# =========
# num_cfs:440, min_perturbs:2.0, prop_perturbs:0.001805054140277207, cf_label 1
# =========
# num_cfs:161, min_perturbs:4.0, prop_perturbs:0.01123595517128706, cf_label 1
# =========
# num_cfs:924, min_perturbs:2.0, prop_perturbs:0.008849557489156723, cf_label 1
# =========
# num_cfs:286, min_perturbs:46.0, prop_perturbs:0.11734693497419357, cf_label 1
# =========
# num_cfs:140, min_perturbs:2.0, prop_perturbs:0.0019267823081463575, cf_label 1
# =========
# num_cfs:405, min_perturbs:4.0, prop_perturbs:0.014388489536941051, cf_label 1
# =========
# num_cfs:565, min_perturbs:2.0, prop_perturbs:0.01886792480945587, cf_label 1
# =========
# num_cfs:479, min_perturbs:2.0, prop_perturbs:0.0042553190141916275, cf_label 1
# =========
# num_cfs:367, min_perturbs:2.0, prop_perturbs:0.004310344811528921, cf_label 1
# =========
# num_cfs:401, min_perturbs:4.0, prop_perturbs:0.02083333395421505, cf_label 1
# =========
# num_cfs:194, min_perturbs:2.0, prop_perturbs:0.007575757801532745, cf_label 1
# =========
# num_cfs:469, min_perturbs:2.0, prop_perturbs:0.0018382353009656072, cf_label 1
# =========
# num_cfs:377, min_perturbs:4.0, prop_perturbs:0.007633587811142206, cf_label 1
# =========
# num_cfs:82, min_perturbs:6.0, prop_perturbs:0.06122449040412903, cf_label 0
# =========
# num_cfs:44, min_perturbs:8.0, prop_perturbs:0.007827788591384888, cf_label 1
# =========
# num_cfs:452, min_perturbs:2.0, prop_perturbs:0.0014430014416575432, cf_label 1
# =========
# num_cfs:677, min_perturbs:2.0, prop_perturbs:0.008333333767950535, cf_label 1
# =========
# num_cfs:19, min_perturbs:14.0, prop_perturbs:0.01411290280520916, cf_label 1
# =========
# num_cfs:888, min_perturbs:4.0, prop_perturbs:0.008510638028383255, cf_label 1
# =========
# num_cfs:784, min_perturbs:2.0, prop_perturbs:0.007042253389954567, cf_label 1
# =========
# num_cfs:669, min_perturbs:2.0, prop_perturbs:0.004464285913854837, cf_label 1
# =========
# num_cfs:405, min_perturbs:2.0, prop_perturbs:0.009523809887468815, cf_label 1
# =========
# num_cfs:951, min_perturbs:2.0, prop_perturbs:0.010989011265337467, cf_label 1
# =========
# num_cfs:801, min_perturbs:2.0, prop_perturbs:0.0031152646988630295, cf_label 1
# =========
# num_cfs:176, min_perturbs:44.0, prop_perturbs:0.08429118245840073, cf_label 1
# =========
# num_cfs:399, min_perturbs:4.0, prop_perturbs:0.0052770450711250305, cf_label 1
# =========
# num_cfs:111, min_perturbs:2.0, prop_perturbs:0.009009009227156639, cf_label 1
# =========
# num_cfs:18, min_perturbs:2.0, prop_perturbs:0.02222222276031971, cf_label 1
# =========
# num_cfs:171, min_perturbs:2.0, prop_perturbs:0.007633587811142206, cf_label 1
# =========
# num_cfs:364, min_perturbs:2.0, prop_perturbs:0.0017123287543654442, cf_label 1
# =========
# num_cfs:650, min_perturbs:2.0, prop_perturbs:0.007518797181546688, cf_label 1
# =========
# num_cfs:464, min_perturbs:2.0, prop_perturbs:0.002197802299633622, cf_label 1
# =========
# num_cfs:147, min_perturbs:2.0, prop_perturbs:0.00390625, cf_label 1
# =========
# num_cfs:654, min_perturbs:2.0, prop_perturbs:0.02500000037252903, cf_label 1
# =========
# num_cfs:362, min_perturbs:2.0, prop_perturbs:0.004739336669445038, cf_label 1
# =========
# num_cfs:95, min_perturbs:42.0, prop_perturbs:0.19266054034233093, cf_label 1
# =========
# ######
# size: 1.5930232558139534, num_success: 86, prop_perturbs: 0.007735556457191706
# finished
# Fedility: 0.7288135593220338, Num_perturbs: 1.5930232558139534, Similarity: 0.992264449596405

# %%
def explaine(model, data, explainer, seed=42):
    seed_everything(seed, deterministic=True)
    result = []
    
    ###
    # only gender = 1
    condition = ((data.test_mask.cpu() | data.val_mask.cpu()) & ~data.x[:,1].to(bool).cpu())
    ###
    df_cf = np.where(condition)[0].tolist()

    print(len(df_cf))
    
    explainer = Explainer(
        model=model,
        algorithm=explainer,
        explanation_type='model',
        node_mask_type=None,
        edge_mask_type='object',
        model_config=dict(
            mode='multiclass_classification',
            task_level='node',
            return_type='raw',
        ), 
    )
    
    # cfs = []
    num_perturbs = []
    prop_perturbs = []

    for i in tqdm(df_cf):
        explanation = explainer(data.x, data.edge_index, index=i)
        
        if hasattr(explanation, "perturbs"):
            if explanation.perturbs < 20:
                # cfs.append(explanation.cf)
                num_perturbs.append(explanation.perturbs)
                prop_perturbs.append(explanation.prop_perturbs)
    
    size, prop = results(num_perturbs, prop_perturbs)
    
    result.append([len(df_cf), size, len(num_perturbs), prop])
    print(f"Fedility: {len(num_perturbs)/len(df_cf)}, Num_perturbs: {size}, Similarity: {1-prop}")
    return result

model = torch.load("../models/Biased_GCN_LoanDecision.pt")
model

explainer = ARExplainer(epochs=1000, lr=0.001, undirected=True, AR_mode=True)
result4 = explaine(model, data, explainer, seed=42)
# Out:
# 82
#   0%|          | 0/82 [00:00<?, ?it/s]
# num_cfs:608, min_perturbs:12.0, prop_perturbs:0.008253094740211964, cf_label 0
# =========
# num_cfs:401, min_perturbs:4.0, prop_perturbs:0.004123711492866278, cf_label 1
# =========
# num_cfs:629, min_perturbs:66.0, prop_perturbs:0.04019488766789436, cf_label 0
# =========
# num_cfs:122, min_perturbs:4.0, prop_perturbs:0.014598540030419827, cf_label 1
# =========
# num_cfs:585, min_perturbs:2.0, prop_perturbs:0.001240694778971374, cf_label 0
# =========
# num_cfs:51, min_perturbs:20.0, prop_perturbs:0.04672896862030029, cf_label 1
# =========
# num_cfs:188, min_perturbs:8.0, prop_perturbs:0.019607843831181526, cf_label 1
# =========
# num_cfs:334, min_perturbs:34.0, prop_perturbs:0.11564625799655914, cf_label 0
# =========
# num_cfs:693, min_perturbs:2.0, prop_perturbs:0.004166666883975267, cf_label 1
# =========
# num_cfs:57, min_perturbs:10.0, prop_perturbs:0.006468305364251137, cf_label 1
# =========
# num_cfs:262, min_perturbs:2.0, prop_perturbs:0.00283286115154624, cf_label 1
# =========
# num_cfs:403, min_perturbs:2.0, prop_perturbs:0.0020920501556247473, cf_label 1
# =========
# num_cfs:123, min_perturbs:2.0, prop_perturbs:0.0011312217684462667, cf_label 1
# =========
# num_cfs:354, min_perturbs:2.0, prop_perturbs:0.0019646366126835346, cf_label 1
# =========
# num_cfs:152, min_perturbs:12.0, prop_perturbs:0.009463722817599773, cf_label 1
# =========
# num_cfs:894, min_perturbs:2.0, prop_perturbs:0.006756756920367479, cf_label 1
# =========
# num_cfs:51, min_perturbs:10.0, prop_perturbs:0.007012622430920601, cf_label 1
# =========
# num_cfs:855, min_perturbs:2.0, prop_perturbs:0.001336898421868682, cf_label 0
# =========
# num_cfs:463, min_perturbs:2.0, prop_perturbs:0.004694835748523474, cf_label 1
# =========
# num_cfs:773, min_perturbs:12.0, prop_perturbs:0.012195121496915817, cf_label 0
# =========
# num_cfs:142, min_perturbs:14.0, prop_perturbs:0.01525054406374693, cf_label 1
# =========
# num_cfs:836, min_perturbs:2.0, prop_perturbs:0.0012562813935801387, cf_label 0
# =========
# num_cfs:769, min_perturbs:6.0, prop_perturbs:0.013574661687016487, cf_label 1
# =========
# num_cfs:568, min_perturbs:2.0, prop_perturbs:0.00401606410741806, cf_label 1
# =========
# num_cfs:64, min_perturbs:26.0, prop_perturbs:0.0962962955236435, cf_label 1
# =========
# num_cfs:5, min_perturbs:90.0, prop_perturbs:0.06870228797197342, cf_label 1
# =========
# num_cfs:687, min_perturbs:2.0, prop_perturbs:0.0025906735099852085, cf_label 0
# =========
# num_cfs:174, min_perturbs:6.0, prop_perturbs:0.014778325334191322, cf_label 1
# =========
# num_cfs:63, min_perturbs:14.0, prop_perturbs:0.01272727269679308, cf_label 1
# =========
# num_cfs:82, min_perturbs:2.0, prop_perturbs:0.003816793905571103, cf_label 1
# =========
# num_cfs:579, min_perturbs:24.0, prop_perturbs:0.06976744532585144, cf_label 1
# =========
# num_cfs:634, min_perturbs:4.0, prop_perturbs:0.008438818156719208, cf_label 1
# =========
# num_cfs:206, min_perturbs:24.0, prop_perturbs:0.015810277312994003, cf_label 1
# =========
# num_cfs:119, min_perturbs:60.0, prop_perturbs:0.19108280539512634, cf_label 1
# =========
# num_cfs:73, min_perturbs:2.0, prop_perturbs:0.0015923567116260529, cf_label 1
# =========
# num_cfs:569, min_perturbs:22.0, prop_perturbs:0.056410256773233414, cf_label 0
# =========
# num_cfs:292, min_perturbs:4.0, prop_perturbs:0.009999999776482582, cf_label 1
# =========
# num_cfs:132, min_perturbs:32.0, prop_perturbs:0.029250457882881165, cf_label 1
# =========
# num_cfs:374, min_perturbs:22.0, prop_perturbs:0.07051282376050949, cf_label 1
# =========
# num_cfs:70, min_perturbs:8.0, prop_perturbs:0.013559321872889996, cf_label 1
# =========
# num_cfs:110, min_perturbs:14.0, prop_perturbs:0.03743315488100052, cf_label 1
# =========
# num_cfs:307, min_perturbs:2.0, prop_perturbs:0.01666666753590107, cf_label 1
# =========
# num_cfs:347, min_perturbs:14.0, prop_perturbs:0.035175878554582596, cf_label 1
# =========
# num_cfs:247, min_perturbs:80.0, prop_perturbs:0.20512820780277252, cf_label 0
# =========
# num_cfs:863, min_perturbs:2.0, prop_perturbs:0.008196720853447914, cf_label 1
# =========
# num_cfs:326, min_perturbs:2.0, prop_perturbs:0.0015128592494875193, cf_label 1
# =========
# num_cfs:590, min_perturbs:6.0, prop_perturbs:0.10344827175140381, cf_label 1
# =========
# num_cfs:746, min_perturbs:2.0, prop_perturbs:0.008620689623057842, cf_label 1
# =========
# num_cfs:707, min_perturbs:2.0, prop_perturbs:0.004694835748523474, cf_label 1
# =========
# num_cfs:316, min_perturbs:4.0, prop_perturbs:0.016260161995887756, cf_label 1
# =========
# num_cfs:241, min_perturbs:2.0, prop_perturbs:0.00390625, cf_label 1
# =========
# num_cfs:145, min_perturbs:4.0, prop_perturbs:0.010362694039940834, cf_label 1
# =========
# num_cfs:26, min_perturbs:4.0, prop_perturbs:0.0027894002851098776, cf_label 1
# =========
# num_cfs:544, min_perturbs:4.0, prop_perturbs:0.011560693383216858, cf_label 1
# =========
# num_cfs:796, min_perturbs:2.0, prop_perturbs:0.007633587811142206, cf_label 1
# =========
# num_cfs:632, min_perturbs:2.0, prop_perturbs:0.0044843051582574844, cf_label 1
# =========
# num_cfs:216, min_perturbs:14.0, prop_perturbs:0.03333333507180214, cf_label 1
# =========
# num_cfs:616, min_perturbs:4.0, prop_perturbs:0.012121211737394333, cf_label 1
# =========
# num_cfs:110, min_perturbs:18.0, prop_perturbs:0.2647058963775635, cf_label 1
# =========
# ######
# size: 2.74468085106383, num_success: 47, prop_perturbs: 0.016860580071806908
# finished
# Fedility: 0.573170731707317, Num_perturbs: 2.74468085106383, Similarity: 0.9831393957138062

# %%
# 200
# Loading widget...
# ######
# size: 1.1451612903225807, num_success: 186, prop_perturbs: 0.006411443930119276
# finished
# Fedility: 0.93, Num_perturbs: 1.1451612903225807, Similarity: 0.9935885667800903
# CPU times: user 43min 4s, sys: 1.27 s, total: 43min 5s
# Wall time: 42min 41s
